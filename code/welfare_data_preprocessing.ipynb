# %%
import pandas as pd

# %%
df = pd.read_csv("보건복지부_사회복지관 시도별 주소 현황_20231231.csv", encoding = "cp949")

# %%
df
# Out:
#       연번  시도           기관명                                주소          전화번호  \
# 0      1  강원     강릉종합사회복지관       강원도 강릉시 강변로 510, 관리사무소건물 2층  033-653-6375
# 1      2  강원     명륜종합사회복지관                   강원도 원주시 예술관길 25  033-762-8131
# 2      3  강원  밥상공동체종합사회복지관                  강원도 원주시 일산로 81-2  033-766-4933
# 3      4  강원    삼척시종합사회복지관               강원도 삼척시 원당로 2길 72-6  033-573-6168
# 4      5  강원     속초종합사회복지관                    강원도 속초시 먹거리길19  033-631-8761
# ..   ...  ..           ...                               ...           ...
# 476  477  충북     제천종합사회복지관                 충북 제천시 용두대로23길 14  043-644-2983
# 477  478  충북     증평종합사회복지관               충북 증평군 증평읍 송티로76-23  043-838-1906
# 478  479  충북       청주사회복지관  충북 청주시 상당구 영운천로 13-1(청주사회복지관 1층)  043-253-4493
# 479  480  충북     청주종합사회복지관         충북 청주시 흥덕구 1순환로 392 (신봉동)  043-266-4761
# 480  481  충북     충주종합사회복지관                      충북 충주시 주공길 7  043-855-3000
#
#                운영주체        법인유형
# 0           월정사복지재단      사회복지법인
# 1             성불복지회      사회복지법인
# 2         밥상공동체복지재단  사회복지법인(직영)
# 3        원주가톨릭사회복지회      사회복지법인
# 4    대한불교조계종신흥사복지재단      사회복지법인
# ..              ...         ...
# 476      원주가톨릭사회복지회      사회복지법인
# 477            열림재단      사회복지법인
# 478           어린이재단      사회복지법인
# 479        충북현양복지재단      사회복지법인
# 480            열림재단      사회복지법인
#
# [481 rows x 7 columns]

# %%
df = df[['기관명', '주소']]

# %%
df
# Out:
#               기관명                                주소
# 0       강릉종합사회복지관       강원도 강릉시 강변로 510, 관리사무소건물 2층
# 1       명륜종합사회복지관                   강원도 원주시 예술관길 25
# 2    밥상공동체종합사회복지관                  강원도 원주시 일산로 81-2
# 3      삼척시종합사회복지관               강원도 삼척시 원당로 2길 72-6
# 4       속초종합사회복지관                    강원도 속초시 먹거리길19
# ..            ...                               ...
# 476     제천종합사회복지관                 충북 제천시 용두대로23길 14
# 477     증평종합사회복지관               충북 증평군 증평읍 송티로76-23
# 478       청주사회복지관  충북 청주시 상당구 영운천로 13-1(청주사회복지관 1층)
# 479     청주종합사회복지관         충북 청주시 흥덕구 1순환로 392 (신봉동)
# 480     충주종합사회복지관                      충북 충주시 주공길 7
#
# [481 rows x 2 columns]

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 5.2 MB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

geolocator = Nominatim(user_agent="welfare_geocoder")

def get_lat_lon(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return pd.Series([location.latitude, location.longitude])
    except:
        return pd.Series([None, None])
    return pd.Series([None, None])

df[['위도','경도']] = df['주소'].apply(get_lat_lon)

df
# Out:
# /var/folders/bg/09yqnt111t34m8ws2pzns7yh0000gn/T/ipykernel_49658/1689051740.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['위도','경도']] = df['주소'].apply(get_lat_lon)
# /var/folders/bg/09yqnt111t34m8ws2pzns7yh0000gn/T/ipykernel_49658/1689051740.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['위도','경도']] = df['주소'].apply(get_lat_lon)
#               기관명                                주소         위도          경도
# 0       강릉종합사회복지관       강원도 강릉시 강변로 510, 관리사무소건물 2층        NaN         NaN
# 1       명륜종합사회복지관                   강원도 원주시 예술관길 25  37.332656  127.942127
# 2    밥상공동체종합사회복지관                  강원도 원주시 일산로 81-2  37.348609  127.947463
# 3      삼척시종합사회복지관               강원도 삼척시 원당로 2길 72-6        NaN         NaN
# 4       속초종합사회복지관                    강원도 속초시 먹거리길19        NaN         NaN
# ..            ...                               ...        ...         ...
# 476     제천종합사회복지관                 충북 제천시 용두대로23길 14  37.145341  128.197838
# 477     증평종합사회복지관               충북 증평군 증평읍 송티로76-23        NaN         NaN
# 478       청주사회복지관  충북 청주시 상당구 영운천로 13-1(청주사회복지관 1층)        NaN         NaN
# 479     청주종합사회복지관         충북 청주시 흥덕구 1순환로 392 (신봉동)        NaN         NaN
# 480     충주종합사회복지관                      충북 충주시 주공길 7  36.988120  127.936408
#
# [481 rows x 4 columns]

# %%
df.to_csv("welfare_data.csv", encoding = "utf-8")
