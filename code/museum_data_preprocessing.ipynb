# %%
import pandas as pd

# %%
df = pd.read_csv("전국박물관미술관정보표준데이터.csv", encoding = "cp949")
print(df)
# Out:
#                        시설명 박물관미술관구분                  소재지도로명주소  \
# 0                  대청댐물문화관       사립     대전광역시 대덕구 대청로 618-136
# 1                  옛터민속박물관       사립       대전광역시 동구 산내로 321-35
# 2                충남대학교 박물관       대학          대전광역시 유성구 대학로 99
# 3             충남대학교 자연사박물관       대학          대전광역시 유성구 대학로 99
# 4                    SN박물관       사립  제주특별자치도 제주시 구좌읍 금백조로 930
# ...                    ...      ...                       ...
# 2235              박을복자수박물관       사립     서울특별시 강북구 삼양로 149가길53
# 2236              공주민속극박물관       사립     충청남도 공주시 의당면 돌모루1길 40
# 2237                 임립미술관       사립    충청남도 공주시 계룡면 봉곡길 77-13
# 2238              감우재전승기념관       공립     충청북도 음성군 음성읍 생음대로 594
# 2239  제8대 유엔사무총장 반기문 평화기념관       공립     충청북도 음성군 원남면 행치길 15-5
#
#                      소재지지번주소         위도          경도      운영기관전화번호      운영기관명  \
# 0          대전광역시 대덕구 미호동 1-5  36.474483  127.481511  042-930-7332    한국수자원공사
# ...

# %%
df.columns
# Out:
# Index(['시설명', '박물관미술관구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '운영기관전화번호',
#        '운영기관명', '운영홈페이지', '편의시설정보', '평일관람시작시각', '평일관람종료시각', '공휴일관람시작시각',
#        '공휴일관람종료시각', '휴관정보', '어른관람료', '청소년관람료', '어린이관람료', '관람료기타정보', '박물관미술관소개',
#        '교통안내정보', '관리기관전화번호', '관리기관명', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
df['박물관미술관구분'].unique()
# Out:
# array(['사립', '대학', '공립', '국립'], dtype=object)

# %%
df = df[['시설명', '소재지도로명주소', '소재지지번주소', '위도', '경도']]

# %%
df.to_csv("museum_data.csv", encoding="utf-8")
