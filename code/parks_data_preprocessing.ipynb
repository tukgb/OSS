# %%
import pandas as pd

# %%
df = pd.read_csv("전국도시공원정보표준데이터.csv", encoding = "cp949")

# %%
print(df)
# Out:
#               관리번호                      공원명   공원구분 소재지도로명주소  \
# 0      41360-00058                 진접2호도담공원  어린이공원      NaN
# 1      41360-00059                 진접6호한빛공원  어린이공원      NaN
# 2      41360-00060                 진접1호해밀공원  어린이공원      NaN
# 3      41360-00061                 장현3어린이공원  어린이공원      NaN
# 4      41360-00062                 장현3어린이공원  어린이공원      NaN
# ...            ...                      ...    ...      ...
# 18241  41220-00097        3호 소리 수변공원(소사벌택지)   수변공원      NaN
# 18242  41220-00098        4호 소리 수변공원(소사벌택지)   수변공원      NaN
# 18243  41220-00099  5호 물빛3 수변공원(소사벌택지 이곡수변)   수변공원      NaN
# 18244  41220-00100  6호 물빛4 수변공원(소사벌택지 이곡수변)   수변공원      NaN
# 18245  41220-00101        7호 너울 수변공원(소사벌택지)   수변공원      NaN
#
#                           소재지지번주소         위도          경도     공원면적  \
# 0            경기도 남양주시 진접읍 금곡리 970  37.719216  127.191542   3702.0
# 1            경기도 남양주시 진접읍 금곡리 985  37.722118  127.201741   4237.0
# ...

# %%
df.columns
# Out:
# Index(['관리번호', '공원명', '공원구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '공원면적',
#        '공원보유시설(운동시설)', '공원보유시설(유희시설)', '공원보유시설(편익시설)', '공원보유시설(교양시설)',
#        '공원보유시설(기타시설)', '지정고시일', '관리기관명', '전화번호', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
df = df.drop(columns=['관리번호', '소재지도로명주소', '공원보유시설(운동시설)', '공원보유시설(유희시설)', '공원보유시설(편익시설)', '공원보유시설(교양시설)','공원보유시설(기타시설)', '지정고시일', '관리기관명', '전화번호', '데이터기준일자', '제공기관코드', '제공기관명'])

# %%
print(df)
# Out:
#                            공원명   공원구분                     소재지지번주소         위도  \
# 0                     진접2호도담공원  어린이공원        경기도 남양주시 진접읍 금곡리 970  37.719216
# 1                     진접6호한빛공원  어린이공원        경기도 남양주시 진접읍 금곡리 985  37.722118
# 2                     진접1호해밀공원  어린이공원       경기도 남양주시 진접읍 금곡리 1084  37.711999
# 3                     장현3어린이공원  어린이공원      경기도 남양주시 진접읍 장현리 710-2  37.726114
# 4                     장현3어린이공원  어린이공원      경기도 남양주시 진접읍 장현리 710-6  37.723291
# ...                        ...    ...                         ...        ...
# 18241        3호 소리 수변공원(소사벌택지)   수변공원          경기도 평택시 죽백동 737-2공  37.007098
# 18242        4호 소리 수변공원(소사벌택지)   수변공원           경기도 평택시 비전동 1032공  37.004339
# 18243  5호 물빛3 수변공원(소사벌택지 이곡수변)   수변공원           경기도 평택시 비전동 1069공  37.002460
# 18244  6호 물빛4 수변공원(소사벌택지 이곡수변)   수변공원  경기도 평택시 비전동 1065 1093 1099  37.001798
# 18245        7호 너울 수변공원(소사벌택지)   수변공원     경기도 평택시 비전동 966 966-1~6  37.003257
#
#                경도     공원면적
# ...

# %%
df.to_csv("parks_data.csv", encoding="utf-8")
