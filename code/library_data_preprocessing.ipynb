# %%
import pandas as pd

# %%
df = pd.read_csv("전국도서관표준데이터.csv", encoding="cp949")

# %%
print(df)
# Out:
#             도서관명    시도명 시군구명  도서관유형        휴관일 평일운영시작시각 평일운영종료시각 토요일운영시작시각  \
# 0          성내도서관  서울특별시  강동구  공공도서관      매주월요일    09:00    18:00     09:00
# 1          해공도서관  서울특별시  강동구  공공도서관      매주화요일    09:00    18:00     09:00
# 2          강일도서관  서울특별시  강동구  공공도서관      매주화요일    09:00    18:00     09:00
# 3          암사도서관  서울특별시  강동구  공공도서관      매주월요일    09:00    18:00     09:00
# 4          천호도서관  서울특별시  강동구  공공도서관      매주월요일    09:00    18:00     09:00
# ...          ...    ...  ...    ...        ...      ...      ...       ...
# 3513    중앙동작은도서관  광주광역시   북구  작은도서관  토+국가지정공휴일    09:00    18:00     00:00
# 3514   중흥1동작은도서관  광주광역시   북구  작은도서관  토+국가지정공휴일    09:00    18:00     00:00
# 3515  징검다리 작은도서관  광주광역시   북구  작은도서관  토+국가지정공휴일    09:00    18:00     00:00
# 3516     참터작은도서관  광주광역시   북구  작은도서관  토+국가지정공휴일    10:00    18:00     00:00
# 3517    책과벗하는사랑방  광주광역시   북구  작은도서관  토+국가지정공휴일    10:00    18:00     00:00
#
# ...

# %%
df.columns
# Out:
# Index(['도서관명', '시도명', '시군구명', '도서관유형', '휴관일', '평일운영시작시각', '평일운영종료시각',
#        '토요일운영시작시각', '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '열람좌석수', '자료수(도서)',
#        '자료수(연속간행물)', '자료수(비도서)', '대출가능권수', '대출가능일수', '소재지도로명주소', '운영기관명',
#        '도서관전화번호', '부지면적', '건물면적', '홈페이지주소', '위도', '경도', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
df = df[['도서관명', '시도명', '시군구명', '도서관유형', '소재지도로명주소', '위도', '경도']]

print(df)
# Out:
#             도서관명    시도명 시군구명  도서관유형                            소재지도로명주소  \
# 0          성내도서관  서울특별시  강동구  공공도서관    서울특별시 강동구 성안로 106-1 (성내동, 성내도서관)
# 1          해공도서관  서울특별시  강동구  공공도서관      서울특별시 강동구 올림픽로 702 (천호동, 해공공원)
# 2          강일도서관  서울특별시  강동구  공공도서관    서울특별시 강동구 아리수로93길 9-14,4,5층(강일동)
# 3          암사도서관  서울특별시  강동구  공공도서관    서울특별시 강동구 고덕로20길 42 (암사동, 암사도서관)
# 4          천호도서관  서울특별시  강동구  공공도서관     서울특별시 강동구 성안로31마길 1(천호동, 천호도서관)
# ...          ...    ...  ...    ...                                 ...
# 3513    중앙동작은도서관  광주광역시   북구  작은도서관       광주광역시 북구 금재로 30(중앙동 행정복지센터 내)
# 3514   중흥1동작은도서관  광주광역시   북구  작은도서관  광주광역시 북구 중흥로183번길 7(중흥1동 행정복지센터 내)
# 3515  징검다리 작은도서관  광주광역시   북구  작은도서관   광주광역시 북구 하서로 195(양산동 광주북구가족센터 2층)
# 3516     참터작은도서관  광주광역시   북구  작은도서관                광주광역시 북구 용주로 30번길 16
# 3517    책과벗하는사랑방  광주광역시   북구  작은도서관                광주광역시 북구 매곡로 93(매곡동)
#
#              위도          경도
# 0     37.532846  127.133328
# 1     37.543948  127.125538
# ...

# %%
df.to_csv("library_data.csv", encoding="utf-8")
