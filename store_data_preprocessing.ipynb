# %% [markdown]
# # 경기도

# %%
import pandas as pd

df = pd.read_csv('상가정보_경기.csv', encoding='utf-8')
print(df.head())
# Out:
#                  상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220802766751  이제이헤어팩토리  NaN        S2    수리·개인      S207
# 1  MA010120220802767250  MisoNail  NaN        S2    수리·개인      S207
# 2  MA010120220802767564     세덴파주점  NaN        S2    수리·개인      S203
# 3  MA010120220802767584     마스터24  NaN        G2       소매      G208
# 4  MA010120220802765290      꼬마나무  NaN        S2    수리·개인      S206
#
#      상권업종중분류명 상권업종소분류코드            상권업종소분류명 표준산업분류코드  ...  \
# 0       이용·미용    S20701                 미용실   S96112  ...
# 1       이용·미용    S20703                 네일숍   S96119  ...
# 2   자동차 수리·세차    S20301             자동차 정비소   S95212  ...
# 3    가전·통신 소매    G20803            가전제품 소매업   G47320  ...
# 4  기타 가정용품 수리    S20699  그 외 기타 개인/가정용품 수리업   S95399  ...
#
#                       건물관리번호              건물명               도로명주소     구우편번호  \
# 0  4148025927116980000018393  책향기마을동문굿모닝힐10단지    경기도 파주시 책향기로 439  413785.0
# ...

# %%
df['상권업종중분류명'].unique()
# Out:
# array(['이용·미용', '자동차 수리·세차', '가전·통신 소매', '기타 가정용품 수리', '시계·귀금속 소매',
#        '스포츠 서비스', '통신장비 수리', '음료 소매', '부동산 서비스', '인쇄·제품제작', '기술 서비스',
#        '자동차 부품 소매', '본사·경영 컨설팅', '애완동물·용품 소매', '주점', '기타 간이', '한식',
#        '담배 소매', '의원', '섬유·의복·신발 소매', '유원지·오락', '기타 사업 서비스', '연료 소매',
#        '종합 소매', '일반 숙박', '중식', '회계·세무', '의약·화장품 소매', '비알코올 ', '전문 디자인',
#        '수의', '가구 소매', '일식', '광고', '컴퓨터 수리', '철물·건설자재 소매', '가전제품 수리',
#        '산업용품 대여', '기타 교육', '식료품 소매', '세탁', '기타 숙박', '일반 교육', '법무관련 ',
#        '장식품 소매', '기타 전문 과학', '중고 상품 소매', '가정용품 대여', '청소·방제', '오락용품 소매',
#        '구내식당·뷔페', '사무 지원', '기타 생활용품 소매', '여행사·보조', '동남아시아', '시설관리', '서양식',
#        '안경·정밀기기 소매', '기타 보건', '운송장비 대여', '병원', '사진 촬영', '고용 알선', '교육 지원',
#        '장례식장 ', '식물 소매', '욕탕·신체관리', '도서관·사적지', '시장 조사', '기타 상품 소매',
#        '모터사이클 소매', '모터사이클 수리', '조경·유지', '기타 개인', '기타 외국'], dtype=object)

# %%
df['상권업종대분류명'].unique()
# Out:
# array(['수리·개인', '소매', '예술·스포츠', '부동산', '과학·기술', '음식', '보건의료', '시설관리·임대',
#        '숙박', '교육'], dtype=object)

# %%
unique = df['상권업종소분류명'].unique()

# %%
len(unique)
# Out:
# 247

# %%
unique[:50]
# 요리 주점, 치킨, 백반/한정식, 돼지고기 구이/찜, 국수/칼국수, 김밥/만두/분식, 해산물 구이/찜, 중국집, 카페, 피자, 빵/도넛, 닭/오리고기 구이/찜, 일식 카레/돈가스/덮밥, 토스트/샌드위치/샐러드
# 헬스장
# 편의점, 슈퍼 마켓
# Out:
# array(['미용실', '네일숍', '자동차 정비소', '가전제품 소매업', '그 외 기타 개인/가정용품 수리업',
#        '시계/귀금속 소매업', '당구장', '핸드폰/통신장비 수리업', '우유 소매업', '부동산 중개/대리업',
#        '의류/이불 수선업', '명함/간판/광고물 제작', '건축 설계 및 관련 서비스업', '자동차 부품 소매업',
#        '경영 컨설팅업', '애완동물/애완용품 소매업', '요리 주점', '치킨', '백반/한정식', '헬스장',
#        '담배/전자담배 소매업', '내과/소아과 의원', '침구류/커튼 소매업', '노래방', '돼지고기 구이/찜',
#        '전시/컨벤션/행사 대행 서비스업', '국수/칼국수', '피부/비뇨기과 의원', '김밥/만두/분식',
#        '해산물 구이/찜', '주유소', '편의점', '여성 의류 소매업', '펜션', '중국집', '세무사',
#        '무도 유흥 주점', '화장품 소매업', '기타 오락관련 서비스업', '카페', '슈퍼마켓', '시각 디자인업',
#        '동물병원', '피자', '가구 소매업', '빵/도넛', '닭/오리고기 구이/찜', '일식 카레/돈가스/덮밥',
#        '토스트/샌드위치/샐러드', '광고 대행업'], dtype=object)

# %%
unique[50:100]
# 일식 회/초밥, 떡/한과, 생맥주 전문, 아이스크림 할인점, 일반 유흥 주점, 족발/보쌈, 국/탕/찌개류, 뷔페, 그 외 기타 간이 음식점, 베트남식 전문, 채소/과일 소매업, 버거
# 기타 스포츠시설 운영업
# 입시·교과학원, 태권도/무술학원
# Out:
# array(['가정용 연료 소매업', '일식 회/초밥', '피부 관리실', '인테리어 디자인업', '약국',
#        '컴퓨터/노트북/프린터 수리업', '철물/공구 소매업', '가전제품 수리업', '기타 의류 소매업',
#        '컴퓨터/사무기기 대여업', '음악학원', '떡/한과', '골프 연습장', '건강보조식품 소매업', '셀프 빨래방',
#        '기타 스포츠시설 운영업', '기숙사/고시원', '타이어 소매업', '핸드폰 소매업', '생맥주 전문',
#        '입시·교과학원', '기타 산업용 기계/장비 대여업', '아이스크림 할인점', '일반 유흥 주점', '세탁소',
#        '행정사', '생수/음료 소매업', '족발/보쌈', '국/탕/찌개류', '정육점', '예술품 소매업',
#        '번역/통역 서비스업', '중고 상품 소매업', '의류 대여업', '소독; 구충 및 방제 서비스업', '자전거 소매업',
#        '뷔페', '기타 사무 지원 서비스업', '건축물 일반 청소업', '악기 소매업', '여행사', '태권도/무술학원',
#        '그 외 기타 간이 음식점', '베트남식 전문', '기타 개인/가정용품 대여업', '건어물/젓갈 소매업',
#        '여관/모텔', '사업시설 유지·관리 서비스업', '채소/과일 소매업', '버거'], dtype=object)

# %%
unique[100:150]
# 횟집, 경양식, 파스타/스테이크, 마라탕/훠궈, 곱창 전골/구이, 아이스크림/빙수, 소고기 구이/찜
# 요가/필라테스 학원
# 그 외 기타 교육기관
# Out:
# array(['횟집', '건물 및 토목 엔지니어링 서비스업', '치과의원', '운동용품 소매업', '반찬/식료품 소매업',
#        '경양식', '남성 의류 소매업', '자동차 세차장', '한의원', '서점', '포장/충전업', '요가/필라테스 학원',
#        '파스타/스테이크', '그 외 기타 교육기관', '안경렌즈 소매업', '환경 관련 엔지니어링 서비스업', '탁구장',
#        '기타 한식 음식점', '광고물 설계/제작업', '유사 의료업', '기타 기술/직업 훈련학원',
#        '기타 엔지니어링 서비스업', '기타 운송장비 대여업', '기타 오락장', 'PC방',
#        '도시 계획 및 조경 설계 서비스업', '가스 충전소', '마라탕/훠궈', '주방/가정용품 소매업',
#        '그 외 기타 종합 소매업', '곱창 전골/구이', '신발 소매업', '전기용품/조명장치 소매업',
#        '벽지/장판/마루 소매업', '수영장', '아이스크림/빙수', '일반병원', '사진촬영업', '자동차 대여업',
#        '장난감 소매업', '임시/일용 인력 공급업', '교육컨설팅업', '기타 건설/건축자재 소매업', '소고기 구이/찜',
#        '운전학원', '가방 소매업', '화장터/묘지/납골당', '복 요리 전문', '꽃집', '체형/비만 관리'],
#       dtype=object)

# %%
unique[150:200]
# 냉면/밀면
# 독서실/스터디 카페, 기타 교육지원 서비스업, 외국어학원, 미술학원, 기타 예술/스포츠 교육기관
# Out:
# array(['패션/섬유/기타 전문 디자인업', '복권 발행/판매업', '독서실/스터디 카페', '수산물 소매업',
#        '목욕탕/사우나', '광고 매체 판매업', '의료기기 소매업', '액세서리/잡화 소매업', '법무사',
#        '건설기계/장비 대여업', '직원 훈련기관', '냉면/밀면', '상용 인력 공급 및 인사관리 서비스업', '볼링장',
#        '한복 소매업', '시장 조사 및 여론 조사업', '변호사', '청소년 수련시설', '그 외 기타 상품 전문 소매업',
#        '고용 알선업', '사업/무형 재산권 중개업', '기타 교육지원 서비스업', '제품 디자인업',
#        '모터사이클 및 부품 소매업', '문구/회화용품 소매업', '스포츠/레크리에이션 용품 대여업', '마사지/안마',
#        '사회교육시설', '외국어학원', '컴퓨터/소프트웨어 소매업', '장례식장', '모터사이클 수리업',
#        '사무기기 소매업', '구내식당', '캠핑/글램핑', '미술학원', '호텔/리조트', '유아용 의류 소매업',
#        '조경 유지·관리 서비스업', '신경/정신과 의원', '기타 예술/스포츠 교육기관', '복사업',
#        '건설/건축자재 소매업', '기념품점', '기타 광고 관련 서비스업', '테니스장', '레크리에이션 교육기관',
#        '실/섬유제품 소매업', '낚시터 운영업', '산업설비; 운송장비 및 공공장소 청소업'], dtype=object)

# %%
unique[200:]
# 일식 면 요리, 주류 소매업, 기타 일식 음식점, 전/부침개, 기타 동남아식 전문, 패밀리레스토랑, 기타 서양식 음식점, 분류 안된 외국식 음식점
# 컴퓨터 학원, 전문자격/고시학원
# Out:
# array(['기타 여행 보조/예약 서비스업', '안과 의원', '공인회계사', '결혼 상담 서비스업', '종합 스포츠시설',
#        '일식 면 요리', '예식장업', '방사선 진단/병리 검사 의원', '주류 소매업', '스쿼시/라켓볼장',
#        '공인노무사', '음반/비디오물 소매업', '기타 법무관련 서비스업', '외과 의원', '전자 게임장',
#        '가죽/가방/신발 수선업', '옥외/전시 광고 대행업', '산부인과 의원', '요양병원', '변리사', '치과병원',
#        '가축 사료 소매업', '만화방', '성형외과 의원', '얼음 소매업', '기타 일식 음식점', '전/부침개',
#        '기타 의원', '사진기/기타 광학기기 소매업', '곡물/곡분 소매업', '수상/해양 레저업', '그 외 기타 숙박업',
#        '기타 동남아식 전문', '이비인후과 의원', '음반/비디오물 대여업', '패밀리레스토랑',
#        '바둑/장기/체스 경기 운영업', '가발 소매업', '기타 서양식 음식점', '컴퓨터 학원',
#        '시계/귀금속/악기 수리업', '한방병원', '종합병원', '비디오방', '전문자격/고시학원',
#        '기타 회계 관련 서비스업', '분류 안된 외국식 음식점'], dtype=object)

# %%
food = ['요리 주점', '치킨', '백반/한정식', '돼지고기 구이/찜', '국수/칼국수', '김밥/만두/분식', '해산물 구이/찜', '중국집', '카페', '피자', '빵/도넛', '닭/오리고기 구이/찜', '일식 카레/돈가스/덮밥', '토스트/샌드위치/샐러드', '일식 회/초밥', '떡/한과', '생맥주 전문', '아이스크림 할인점', '일반 유흥 주점', '족발/보쌈', '국/탕/찌개류', '뷔페', '그 외 기타 간이 음식점', '베트남식 전문', '채소/과일 소매업', '버거', '횟집', '경양식', '파스타/스테이크', '마라탕/훠궈', '곱창 전골/구이', '아이스크림/빙수', '소고기 구이/찜', '냉면/밀면', '일식 면 요리', '주류 소매업', '기타 일식 음식점', '전/부침개', '기타 동남아식 전문', '패밀리레스토랑', '기타 서양식 음식점', '분류 안된 외국식 음식점']

# %%
df_filtered = df[df['상권업종소분류명'].isin(food)][
    ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']
]

print(df_filtered)
# Out:
#                상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명                        도로명주소  \
# 20          별밤노래주점       음식       주점      요리 주점       경기도 포천시 소흘읍 솔모루로98번길 2
# 21        처갓집치킨묵현점       음식    기타 간이         치킨       경기도 남양주시 화도읍 먹갓로28번길 5
# 22            디알식당       음식       한식     백반/한정식        경기도 화성시 장안면 석포로 360-4
# 27             별이네       음식       한식     백반/한정식     경기도 화성시 송산면 사강시장길43번길 26
# 29         정이가는쪽갈비       음식       한식  돼지고기 구이/찜           경기도 화성시 지산1길 21-10
# ...            ...      ...      ...        ...                          ...
# 651424        트리아농       음식    비알코올          카페    경기도 용인시 수지구 죽전로144번길 15-4
# 651425  신대해500원양꼬치       음식       중식        중국집        경기도 안성시 중앙로362번길 19-7
# 651427          설경       음식       중식        중국집      경기도 김포시 김포한강9로12번길 7-18
# 651428         푸라닭       음식    기타 간이         치킨               경기도 시흥시 남왕길 40
# 651431       장호짤라집       음식       한식    국/탕/찌개류  경기도 이천시 호법면 프리미엄아울렛로 177-74
#
# ...

# %%
df_food = df[df['상권업종대분류명'] == '음식'][
    ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']
]

print(df_food)
# Out:
#                상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명                        도로명주소  \
# 20          별밤노래주점       음식       주점      요리 주점       경기도 포천시 소흘읍 솔모루로98번길 2
# 21        처갓집치킨묵현점       음식    기타 간이         치킨       경기도 남양주시 화도읍 먹갓로28번길 5
# 22            디알식당       음식       한식     백반/한정식        경기도 화성시 장안면 석포로 360-4
# 27             별이네       음식       한식     백반/한정식     경기도 화성시 송산면 사강시장길43번길 26
# 29         정이가는쪽갈비       음식       한식  돼지고기 구이/찜           경기도 화성시 지산1길 21-10
# ...            ...      ...      ...        ...                          ...
# 651424        트리아농       음식    비알코올          카페    경기도 용인시 수지구 죽전로144번길 15-4
# 651425  신대해500원양꼬치       음식       중식        중국집        경기도 안성시 중앙로362번길 19-7
# 651427          설경       음식       중식        중국집      경기도 김포시 김포한강9로12번길 7-18
# 651428         푸라닭       음식    기타 간이         치킨               경기도 시흥시 남왕길 40
# 651431       장호짤라집       음식       한식    국/탕/찌개류  경기도 이천시 호법면 프리미엄아울렛로 177-74
#
# ...

# %%
df_food.to_csv('food_industry_data.csv', index = False, encoding = 'utf-8-sig')

# %%
print(df[df['상권업종소분류명'] == '편의점'])
# Out:
#                       상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 39      MA010120220801413484  세븐일레븐화성조암점  NaN        G2       소매      G204
# 94      MA010120220801407887   미니스톱오산우리점  NaN        G2       소매      G204
# 138     MA010120220805105079  씨유수원삼성SDI점  NaN        G2       소매      G204
# 144     MA010120220801418225      GS25태안  남산점        G2       소매      G204
# 151     MA010120220802775534  세븐일레븐파주두일점  NaN        G2       소매      G204
# ...                      ...         ...  ...       ...      ...       ...
# 651187  MA010120220805465052   씨유동탄반송원룸점  NaN        G2       소매      G204
# 651221  MA010120220808517822          굿샵  별내점        G2       소매      G204
# 651246  MA010120220801297379    코레일유통당정역  NaN        G2       소매      G204
# 651260  MA010120220801671958     씨유퍼스트빌점  NaN        G2       소매      G204
# 651410  MA010120220801316441     지에스25과천  중앙점        G2       소매      G204
#
# ...

# %%
print(df[df['상권업종소분류명'] == '슈퍼마켓'])
# Out:
#                       상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 53      MA010120220801406481    지은마트  NaN        G2       소매      G204
# 70      MA010120220805104135     라피네  NaN        G2       소매      G204
# 81      MA010120220807371188      명당  NaN        G2       소매      G204
# 191     MA010120220803885300    슈퍼마켓  NaN        G2       소매      G204
# 356     MA010120220808512862    지산유통  NaN        G2       소매      G204
# ...                      ...     ...  ...       ...      ...       ...
# 651180  MA010120220801810774  마을회관슈퍼  NaN        G2       소매      G204
# 651204  MA010120220805074448    농민마트  NaN        G2       소매      G204
# 651213  MA010120220807371263      큐팜  NaN        G2       소매      G204
# 651240  MA010120220812731460     비아이  NaN        G2       소매      G204
# 651386  MA010120220808505270    친구79  NaN        G2       소매      G204
#
#        상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
df[df['상권업종중분류명'] == '종합 소매']['상권업종소분류명'].unique()
# Out:
# array(['편의점', '슈퍼마켓', '그 외 기타 종합 소매업'], dtype=object)

# %%
df[df['상권업종소분류명'] == '그 외 기타 종합 소매업']['상호명']
# Out:
# 423             행복한세상
# 442            골프존마을샵
# 790           하나더DC마트
# 857       왕도매신발;의류;잡화
# 1544             청솔매점
#              ...
# 649231           베스트올
# 649751     에이치와이밸류업지점
# 649756          엠티글로벌
# 649927            제이원
# 651309            한마음
# Name: 상호명, Length: 1605, dtype: object

# %%
df_store = df[(df['상권업종소분류명'] == '편의점') | (df['상권업종소분류명'] == '슈퍼마켓')][
    ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']
]

print(df_store)
# Out:
#                상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명                   도로명주소  \
# 39      세븐일레븐화성조암점       소매    종합 소매      편의점  경기도 화성시 우정읍 조암남로33번길 6
# 53            지은마트       소매    종합 소매     슈퍼마켓     경기도 오산시 오산로358번길 19
# 70             라피네       소매    종합 소매     슈퍼마켓    경기도 양주시 백석읍 꿈나무로 200
# 81              명당       소매    종합 소매     슈퍼마켓     경기도 남양주시 와부읍 수레로 10
# 94       미니스톱오산우리점       소매    종합 소매      편의점      경기도 오산시 궐동로69번길 31
# ...            ...      ...      ...      ...                     ...
# 651240         비아이       소매    종합 소매     슈퍼마켓      경기도 화성시 꽃내음2길 56-7
# 651246    코레일유통당정역       소매    종합 소매      편의점         경기도 군포시 당정역로 91
# 651260     씨유퍼스트빌점       소매    종합 소매      편의점         경기도 의정부시 시민로 29
# 651386        친구79       소매    종합 소매     슈퍼마켓      경기도 평택시 중앙시장로 16-7
# 651410     지에스25과천       소매    종합 소매      편의점         경기도 과천시 중앙로 137
#
#            구우편번호  신우편번호          경도         위도
# 39      445955.0  18567  126.818801  37.084527
# ...

# %%
df_store.to_csv('convenience_store_data.csv', index = False, encoding = 'utf-8-sig')

# %%
df[df['상권업종대분류명'] == '예술·스포츠']['상권업종중분류명'].unique()
# Out:
# array(['스포츠 서비스', '유원지·오락', '도서관·사적지'], dtype=object)

# %%
df[df['상권업종중분류명'] == '스포츠 서비스']['상권업종소분류명'].unique()
# Out:
# array(['당구장', '헬스장', '골프 연습장', '기타 스포츠시설 운영업', '탁구장', '수영장', '볼링장',
#        '테니스장', '종합 스포츠시설', '스쿼시/라켓볼장'], dtype=object)

# %%
df[df['상권업종소분류명'] == '종합 스포츠시설']['상호명']
# Out:
# 2530           피닉스스포츠센터
# 14427             알유스포츠
# 14706              힐링점핑
# 23230             아이스포츠
# 30287           키플스포츠클럽
#               ...
# 630337    대한장애인체육회이천선수촌
# 635255      코오롱글로벌스포렉스주
# 640976         구갈스포츠센타주
# 643703         바디오프퍼스널짐
# 648584      코오롱글로벌스포렉스주
# Name: 상호명, Length: 176, dtype: object

# %%
df[df['상권업종소분류명'] == '기타 스포츠시설 운영업']['상호명']
# Out:
# 109         쏘폴스튜디오
# 4096          배팅클럽
# 5480         경희야구장
# 6140        클라임바운스
# 6783        다함께야구왕
#             ...
# 641332    김포베이스볼클럽
# 644889        테마공원
# 647913       스크린야구
# 648249       오해피점핑
# 648632          씨팍
# Name: 상호명, Length: 610, dtype: object

# %%
df_sports = df[df['상권업종중분류명'] == '스포츠 서비스'][
    ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']
]

print(df_sports)
# Out:
#                 상호명 상권업종대분류명 상권업종중분류명      상권업종소분류명  \
# 6            777당구장   예술·스포츠  스포츠 서비스           당구장
# 23            올웨이즈핏   예술·스포츠  스포츠 서비스           헬스장
# 96            고향당구장   예술·스포츠  스포츠 서비스           당구장
# 102        훼밀리스크린골프   예술·스포츠  스포츠 서비스        골프 연습장
# 109          쏘폴스튜디오   예술·스포츠  스포츠 서비스  기타 스포츠시설 운영업
# ...             ...      ...      ...           ...
# 651078       웨돔당구클럽   예술·스포츠  스포츠 서비스           당구장
# 651084  골프존파크양주와이드점   예술·스포츠  스포츠 서비스        골프 연습장
# 651222       안양탁구클럽   예술·스포츠  스포츠 서비스           탁구장
# 651344       패밀리키즈풀   예술·스포츠  스포츠 서비스           수영장
# 651361       프리덤씨엔지   예술·스포츠  스포츠 서비스           당구장
#
#                              도로명주소     구우편번호  신우편번호          경도         위도
# 6                 경기도 오산시 성호대로 130  447060.0  18139  127.075801  37.148473
# 23             경기도 평택시 평택5로34번길 22  450020.0  17902  127.112824  36.989521
# 96             경기도 화성시 우정읍 매바위로 70  445956.0  18559  126.816978  37.122054
# ...

# %%
df_sports.to_csv('sports_center_data.csv', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # 강원도

# %%
gwd = pd.read_csv('상가정보_강원.csv', encoding='utf-8')
print(gwd.head())
# Out:
#                  상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  MA010120220807371663  술샘짬뽕타운  NaN        I2       음식      I202         중식
# 1  MA010120220803876241     용우동  NaN        I2       음식      I210      기타 간이
# 2  MA010120220809679479   둥지소주방  NaN        I2       음식      I201         한식
# 3  MA010120220809684885      유디  NaN        I2       음식      I212      비알코올
# 4  MA010120220807370491    동우씨엠  NaN        G2       소매      G215  의약·화장품 소매
#
#   상권업종소분류코드  상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0    I20201       중국집   I56121  ...  4275036021112610001011223  NaN
# 1    I21007  김밥/만두/분식   I56194  ...  4275025022102530038019406  NaN
# 2    I20101    백반/한정식   I56111  ...  4276038024102080001000001  NaN
# 3    I21201        카페   I56229  ...  4211025024103080021000001  NaN
# 4    G21503   화장품 소매업   G47813  ...  4276025023100370000025568  NaN
#
#                         도로명주소   구우편번호  신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
gwd_food = gwd[gwd['상권업종대분류명'] == '음식'][
    ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']
]

print(gwd_food)
# Out:
#                상호명 상권업종대분류명 상권업종중분류명  상권업종소분류명                        도로명주소  \
# 0           술샘짬뽕타운       음식       중식       중국집   강원특별자치도 영월군 주천면 주천로58번길 29
# 1              용우동       음식    기타 간이  김밥/만두/분식      강원특별자치도 영월군 영월읍 중앙1로 22
# 2            둥지소주방       음식       한식    백반/한정식   강원특별자치도 평창군 대관령면 대관령마루길 76
# 3               유디       음식    비알코올         카페    강원특별자치도 춘천시 신북읍 장본길 54-10
# 10      카페로천커피&전통차       음식    비알코올         카페  강원특별자치도 평창군 대관령면 솔봉로 173-32
# ...            ...      ...      ...       ...                          ...
# 107546         새벽집       음식       한식    백반/한정식           강원특별자치도 강릉시 옥천로 71
# 107547     도미노피자춘천       음식    기타 간이        피자          강원특별자치도 춘천시 춘천로 247
# 107551          드문       음식    비알코올         카페        강원특별자치도 원주시 송림길 52-22
# 107554         에이스       음식    비알코올         카페      강원특별자치도 평창군 봉평면 경강로 551
# 107560    배스킨라빈스춘천       음식    기타 간이  아이스크림/빙수         강원특별자치도 춘천시 안마산로 115
#
#          구우편번호  신우편번호          경도         위도
# ...

# %%
gwd_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %%
gwd_store = gwd[(gwd['상권업종소분류명'] == '편의점') | (gwd['상권업종소분류명'] == '슈퍼마켓')][
    ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']
]

print(gwd_store)
# Out:
#                상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명                        도로명주소  \
# 59             연마트       소매    종합 소매     슈퍼마켓   강원특별자치도 횡성군 우천면 한우로우항2길 37
# 95            홍천마트       소매    종합 소매     슈퍼마켓       강원특별자치도 철원군 근남면 육단2길 5
# 112           봉명슈퍼       소매    종합 소매     슈퍼마켓       강원특별자치도 철원군 동송읍 이평로 85
# 115           영풍마트       소매    종합 소매     슈퍼마켓      강원특별자치도 철원군 김화읍 김화로 614
# 132      미니스톱양양강선점       소매    종합 소매      편의점    강원특별자치도 양양군 강현면 물치천로 70-4
# ...            ...      ...      ...      ...                          ...
# 107532         강&별       소매    종합 소매     슈퍼마켓     강원특별자치도 영월군 영월읍 동강로 1503
# 107537  씨유춘천부영하모니점       소매    종합 소매      편의점  강원특별자치도 춘천시 동내면 거두택지길 41-94
# 107553    얼음골야영장슈퍼       소매    종합 소매     슈퍼마켓       강원특별자치도 양양군 서면 얼음골길 50
# 107557       세븐일레븐       소매    종합 소매      편의점          강원특별자치도 강릉시 선수촌로 32
# 107561     세븐원주법원점       소매    종합 소매      편의점           강원특별자치도 원주시 봉바위길 3
#
#          구우편번호  신우편번호          경도         위도
# ...

# %%
gwd_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %%
gwd_sports = gwd[gwd['상권업종중분류명'] == '스포츠 서비스'][
    ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']
]

print(gwd_sports)
# Out:
#                상호명 상권업종대분류명 상권업종중분류명      상권업종소분류명  \
# 66        골프존동내다원점   예술·스포츠  스포츠 서비스        골프 연습장
# 96          대암홀스랜드   예술·스포츠  스포츠 서비스  기타 스포츠시설 운영업
# 186              핏   예술·스포츠  스포츠 서비스           헬스장
# 238     팀샤크스윔앤피트니스   예술·스포츠  스포츠 서비스           헬스장
# 361           청년헬스   예술·스포츠  스포츠 서비스           헬스장
# ...            ...      ...      ...           ...
# 107226       스크린골프   예술·스포츠  스포츠 서비스        골프 연습장
# 107276       다올스크린   예술·스포츠  스포츠 서비스        골프 연습장
# 107296    횡성골프존스크린   예술·스포츠  스포츠 서비스        골프 연습장
# 107337         머슬핏   예술·스포츠  스포츠 서비스           헬스장
# 107373   에콜리안정선골프장   예술·스포츠  스포츠 서비스        골프 연습장
#
#                              도로명주소   구우편번호  신우편번호          경도         위도
# 66       강원특별자치도 춘천시 동내면 춘천순환로 171  200883  24400  127.761414  37.858145
# 96         강원특별자치도 철원군 갈말읍 태봉로 871  269804  24030  127.384388  38.182437
# 186      강원특별자치도 홍천군 홍천읍 남산마을길3길 9  250930  25147  127.883227  37.683539
# ...

# %%
gwd_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 경상남도

# %%
gnam = pd.read_csv("상가정보_경남.csv", encoding = "utf-8")

print(gnam)
# Out:
#                       상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220807382126      백반/한정식  NaN        I2       음식      I201
# 1       MA010120220809678928   늘솜창의미술교습소  NaN        P1       교육      P106
# 2       MA010120220805099638         플펜션  NaN        I1       숙박      I101
# 3       MA010120220806280977         용정관  NaN        I2       음식      I202
# 4       MA010120220806280661          이현  NaN        I2       음식      I211
# ...                      ...         ...  ...       ...      ...       ...
# 169915  MA010120220807344191         오스텍  NaN        P1       교육      P107
# 169916  MA010120220809615676  두드림건축/인테리어  NaN        M1    과학·기술      M112
# 169917  MA010120220805008176      색소폰하우스  NaN        I2       음식      I211
# 169918  MA010120220812753231       엠에스제작  NaN        M1    과학·기술      M105
# 169919  MA010120220813732418        가인식당  NaN        I2       음식      I211
#
#        상권업종중분류명 상권업종소분류코드      상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
columns = ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명주소', '구우편번호', '신우편번호', '경도', '위도']

# %%
gnam_food = gnam[gnam['상권업종대분류명'] == '음식'][columns]
gnam_store = gnam[(gnam['상권업종소분류명'] == '편의점') | (gnam['상권업종소분류명'] == '슈퍼마켓')][columns]
gnam_sports = gnam[gnam['상권업종중분류명'] == '스포츠 서비스'][columns]

gnam_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
gnam_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
gnam_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 경상북도

# %%
gb = pd.read_csv("상가정보_경북.csv", encoding = "utf-8")

print(gb)
# Out:
#                       상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220806280680        마트통닭  NaN        I2       음식      I210
# 1       MA010120220803879158  블루뮤직실용음악학원  NaN        P1       교육      P106
# 2       MA010120220807382442   뚜레쥬르구미구평점  NaN        I2       음식      I210
# 3       MA010120220807370537  명품공인중개사사무소  NaN        L1      부동산      L102
# 4       MA010120220808500326       일진종합사  NaN        S2    수리·개인      S205
# ...                      ...         ...  ...       ...      ...       ...
# 142266  MA010120220805029908      성암식육식당  NaN        I2       음식      I201
# 142267  MA010120220805012668        도매식품  NaN        G2       소매      G204
# 142268  MA010120220812780948      굿모닝보청기  NaN        G2       소매      G215
# 142269  MA010120220809566648  포스공인중개사사무소  NaN        L1      부동산      L102
# 142270  MA010120220809566526          럭키  NaN        G2       소매      G213
#
#          상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
gb_food = gb[gb['상권업종대분류명'] == '음식'][columns]
gb_store = gb[(gb['상권업종소분류명'] == '편의점') | (gb['상권업종소분류명'] == '슈퍼마켓')][columns]
gb_sports = gb[gb['상권업종중분류명'] == '스포츠 서비스'][columns]

gb_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
gb_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
gb_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 광주

# %%
gj = pd.read_csv("상가정보_광주.csv", encoding = "utf-8")

print(gj)
# Out:
#                      상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220809684882   지엠에이마샬아츠센터  NaN        P1       교육      P106
# 1      MA010120220809685483         운수대통  NaN        R1   예술·스포츠      R104
# 2      MA010120220808499617       동준정보통신  NaN        G2       소매      G208
# 3      MA010120220803875801         엑스모텔  NaN        I1       숙박      I101
# 4      MA010120220807370799  500도참숯불맛삼겹살  NaN        I2       음식      I201
# ...                     ...          ...  ...       ...      ...       ...
# 74984  MA010120220806634391   세븐광주하남2지구점  코리아        G2       소매      G204
# 74985  MA010120220805444162          더코드  NaN        G2       소매      G209
# 74986  MA010120220803136712         정인축산  NaN        G2       소매      G205
# 74987  MA010120220800097463       엄니민물고기  전문점        I2       음식      I201
# 74988  MA010120220813745010   세움진로학습코칭센터  NaN        P1       교육      P107
#
#           상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
gj_food = gj[gj['상권업종대분류명'] == '음식'][columns]
gj_store = gj[(gj['상권업종소분류명'] == '편의점') | (gj['상권업종소분류명'] == '슈퍼마켓')][columns]
gj_sports = gj[gj['상권업종중분류명'] == '스포츠 서비스'][columns]

gj_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
gj_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
gj_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 대구

# %%
dg = pd.read_csv("상가정보_대구.csv", encoding = "utf-8")

print(dg)
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220803879504      파스칼수학학원  NaN        P1       교육      P105
# 1       MA010120220807370257     구두명품종합병원  NaN        S2    수리·개인      S206
# 2       MA010120220805097970    오렌지나무협동조합  NaN        P1       교육      P107
# 3       MA010120220807371764        고령코다리  NaN        I2       음식      I201
# 4       MA010120220807370526      강지원돼지초밥  NaN        I2       음식      I201
# ...                      ...          ...  ...       ...      ...       ...
# 114919  MA010120220803879643      아리야무용학원  NaN        P1       교육      P106
# 114920  MA010120220805100806    롯데대구헤지스여성  NaN        G2       소매      G209
# 114921  MA010120220808464884       대성종합상사  NaN        G2       소매      G210
# 114922  MA010120220813753347           비원  NaN        I2       음식      I201
# 114923  MA010120220809566522  푸드딜라이트대구신기점  NaN        I2       음식      I210
#
# ...

# %%
dg_food = dg[dg['상권업종대분류명'] == '음식'][columns]
dg_store = dg[(dg['상권업종소분류명'] == '편의점') | (dg['상권업종소분류명'] == '슈퍼마켓')][columns]
dg_sports = dg[dg['상권업종중분류명'] == '스포츠 서비스'][columns]

dg_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
dg_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
dg_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 대전

# %%
dj = pd.read_csv("상가정보_대전.csv", encoding = "utf-8")

print(dj)
# Out:
#                      상가업소번호           상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220806289177        얀헤어컬렉션  NaN        S2    수리·개인      S207
# 1      MA010120220809677617  신옛날양푼이동태대구찌개  NaN        I2       음식      I201
# 2      MA010120220809679407          보물창고  NaN        R1   예술·스포츠      R104
# 3      MA010120220809677924         티이컴퍼니  NaN        N1  시설관리·임대      N108
# 4      MA010120220807370582       집밥먹으러가자  NaN        I2       음식      I201
# ...                     ...           ...  ...       ...      ...       ...
# 77600  MA010120220806238159          카페나루  NaN        I2       음식      I212
# 77601  MA010120220806205964         스타노래방  NaN        R1   예술·스포츠      R104
# 77602  MA010120220806209258     제주고기국수하르방  NaN        I2       음식      I201
# 77603  MA010120220807366198        다모아세탁소  NaN        S2    수리·개인      S209
# 77604  MA010120220812769443        디에스모바일  NaN        G2       소매      G208
#
# ...

# %%
dj_food = dj[dj['상권업종대분류명'] == '음식'][columns]
dj_store = dj[(dj['상권업종소분류명'] == '편의점') | (dj['상권업종소분류명'] == '슈퍼마켓')][columns]
dj_sports = dj[dj['상권업종중분류명'] == '스포츠 서비스'][columns]

dj_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
dj_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
dj_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 부산

# %%
bs = pd.read_csv("상가정보_부산.csv", encoding = "utf-8")

print(bs)
# Out:
#                       상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220805098070     로이파트너스  NaN        M1    과학·기술      M105
# 1       MA010120220805099507       교내매점  NaN        G2       소매      G204
# 2       MA010120220809684948        씨이오  NaN        G2       소매      G202
# 3       MA010120220809679133       온샘의원  NaN        Q1     보건의료      Q102
# 4       MA010120220808500398        유식당  NaN        I2       음식      I201
# ...                      ...        ...  ...       ...      ...       ...
# 154812  MA010120220805076154     이태영헤어샵  NaN        S2    수리·개인      S207
# 154813  MA010120220805091962     릴렉스광복점  코리아        G2       소매      G208
# 154814  MA010120220809671908  롯데광복씨씨콜렉트  NaN        G2       소매      G209
# 154815  MA010120220811773894         다빈  NaN        I2       음식      I212
# 154816  MA010120220813766013        판다네  NaN        G2       소매      G209
#
#            상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
bs_food = bs[bs['상권업종대분류명'] == '음식'][columns]
bs_store = bs[(bs['상권업종소분류명'] == '편의점') | (bs['상권업종소분류명'] == '슈퍼마켓')][columns]
bs_sports = bs[bs['상권업종중분류명'] == '스포츠 서비스'][columns]

bs_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
bs_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
bs_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 서울

# %%
seoul = pd.read_csv("상가정보_서울.csv", encoding = "utf-8")
print(seoul)
# Out:
#                       상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220803882516     피어리스양품  NaN        G2       소매      G209
# 1       MA010120220803882799    삼보금속인쇄소  NaN        M1    과학·기술      M114
# 2       MA010120220800132710     한동규법무사  NaN        M1    과학·기술      M103
# 3       MA010120220809677897  진앤케이엔지니어링  NaN        M1    과학·기술      M109
# 4       MA010120220809678175        까페인  NaN        I2       음식      I212
# ...                      ...        ...  ...       ...      ...       ...
# 536110  MA010120220811815207     무명고시식당  NaN        I2       음식      I201
# 536111  MA010120220812812834      에스와이엘  NaN        I2       음식      I204
# 536112  MA010120220812814040        라플라  NaN        G2       소매      G209
# 536113  MA010120220808409779       목동기원  NaN        R1   예술·스포츠      R104
# 536114  MA010120220803778725         한결  NaN        S2    수리·개인      S207
#
#            상권업종중분류명 상권업종소분류코드         상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
seoul_food = seoul[seoul['상권업종대분류명'] == '음식'][columns]
seoul_store = seoul[(seoul['상권업종소분류명'] == '편의점') | (seoul['상권업종소분류명'] == '슈퍼마켓')][columns]
seoul_sports = seoul[seoul['상권업종중분류명'] == '스포츠 서비스'][columns]

seoul_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
seoul_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
seoul_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 세종

# %%
sj = pd.read_csv("상가정보_세종.csv", encoding = "utf-8")
print(sj)
# Out:
#                      상가업소번호           상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220806293764  세종제일공인중개사사무소   NaN        L1      부동산      L102
# 1      MA010120220805105327         워싱고릴라   NaN        S2    수리·개인      S209
# 2      MA010120220807384771        세종금거래소   NaN        G2       소매      G217
# 3      MA010120220806307009          미소약국   NaN        G2       소매      G215
# 4      MA010120220800141676         진미껍데기   NaN        I2       음식      I201
# ...                     ...           ...   ...       ...      ...       ...
# 14848  MA010120220800522416          삼맛카페   NaN        I2       음식      I212
# 14849  MA010120220808208889         60계치킨  조치원점        I2       음식      I210
# 14850  MA010120220806655076          위드에스   NaN        M1    과학·기술      M105
# 14851  MA010120220808432110        레드앤화이트   NaN        P1       교육      P105
# 14852  MA010120220809610773         세종홈케어   NaN        N1  시설관리·임대      N102
#
# ...

# %%
sj_food = sj[sj['상권업종대분류명'] == '음식'][columns]
sj_store = sj[(sj['상권업종소분류명'] == '편의점') | (sj['상권업종소분류명'] == '슈퍼마켓')][columns]
sj_sports = sj[sj['상권업종중분류명'] == '스포츠 서비스'][columns]

sj_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
sj_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
sj_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 울산

# %%
ulsan = pd.read_csv("상가정보_울산.csv", encoding = "utf-8")
print(ulsan)
# Out:
#                      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220806287705  백선피아노음악학원  NaN        P1       교육      P106
# 1      MA010120220808500469      유필라테스  NaN        P1       교육      P106
# 2      MA010120220809686019     패밀리북카페  NaN        I2       음식      I212
# 3      MA010120220807371036  율동청국장할매식당  NaN        I2       음식      I201
# 4      MA010120220803879975    바이민음악학원  NaN        P1       교육      P106
# ...                     ...        ...  ...       ...      ...       ...
# 53653  MA010120220807721802      러블리스윗  NaN        I2       음식      I210
# 53654  MA010120220810020729        코끼리  NaN        I2       음식      I211
# 53655  MA010120220802270112      백산세탁소  NaN        S2    수리·개인      S209
# 53656  MA010120220805031058      오케이유통  NaN        G2       소매      G204
# 53657  MA010120220811814166         샌느  NaN        S2    수리·개인      S207
#
#       상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
ulsan_food = ulsan[ulsan['상권업종대분류명'] == '음식'][columns]
ulsan_store = ulsan[(ulsan['상권업종소분류명'] == '편의점') | (ulsan['상권업종소분류명'] == '슈퍼마켓')][columns]
ulsan_sports = ulsan[ulsan['상권업종중분류명'] == '스포츠 서비스'][columns]

ulsan_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
ulsan_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
ulsan_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 인천

# %%
ic = pd.read_csv("상가정보_인천.csv", encoding="utf-8")
print(ic)
# Out:
#                       상가업소번호         상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220809685947  우리모두다함께치킨해    NaN        I2       음식      I211
# 1       MA010120220807371779    닥터.지동물병원    NaN        M1    과학·기술      M111
# 2       MA010120220806281546  명인공인중개사사무소    NaN        L1      부동산      L102
# 3       MA010120220805097984      법무법인조우    NaN        M1    과학·기술      M103
# 4       MA010120220809678098   디코레북창동순두부  인천논현점        I2       음식      I201
# ...                      ...         ...    ...       ...      ...       ...
# 133270  MA010120220805002872      오늘도예쁘다    NaN        S2    수리·개인      S207
# 133271  MA010120220811886217       제이앤에스    NaN        M1    과학·기술      M112
# 133272  MA010120220813871762        공간지지    NaN        L1      부동산      L102
# 133273  MA010120220811738082      지앤에이치쿡    NaN        I2       음식      I210
# 133274  MA010120220808395625        행복한가    NaN        I2       음식      I201
#
# ...

# %%
ic_food = ic[ic['상권업종대분류명'] == '음식'][columns]
ic_store = ic[(ic['상권업종소분류명'] == '편의점') | (ic['상권업종소분류명'] == '슈퍼마켓')][columns]
ic_sports = ic[ic['상권업종중분류명'] == '스포츠 서비스'][columns]

ic_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
ic_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
ic_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 전남

# %%
jn = pd.read_csv("상가정보_전남.csv", encoding = "utf-8")
print(jn)
# Out:
#                      상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220807371784     영자네민박  NaN        I1       숙박      I101
# 1      MA010120220809680115    울도숯불갈비  NaN        I2       음식      I201
# 2      MA010120220807370789    벌교희망약국  NaN        G2       소매      G215
# 3      MA010120220800143262      스파티움  NaN        P1       교육      P106
# 4      MA010120220808506438       또오넛  NaN        I2       음식      I212
# ...                     ...       ...  ...       ...      ...       ...
# 99390  MA010120220807839332      연향유리  NaN        G2       소매      G212
# 99391  MA010120220808436121      청담피자  남악점        I2       음식      I210
# 99392  MA010120220808405505     피닉스모텔  NaN        I1       숙박      I101
# 99393  MA010120220813829699      우리식당  NaN        I2       음식      I201
# 99394  MA010120220813717681  나주자연산추어탕  NaN        I2       음식      I201
#
#          상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
jn_food = jn[jn['상권업종대분류명'] == '음식'][columns]
jn_store = jn[(jn['상권업종소분류명'] == '편의점') | (jn['상권업종소분류명'] == '슈퍼마켓')][columns]
jn_sports = jn[jn['상권업종중분류명'] == '스포츠 서비스'][columns]

jn_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
jn_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
jn_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 전북

# %%
jb = pd.read_csv("상가정보_전북.csv", encoding = "utf-8")
print(jb)
# Out:
#                      상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220807380761   동아천막사  NaN        G2       소매      G210
# 1      MA010120220803879382     다수산  NaN        G2       소매      G205
# 2      MA010120220807382368    KJ상사  NaN        G2       소매      G208
# 3      MA010120220807382674  중앙오토바이  NaN        S2    수리·개인      S204
# 4      MA010120220807382675     전일사  NaN        S2    수리·개인      S209
# ...                     ...     ...  ...       ...      ...       ...
# 96652  MA010120220807322537    카페베네  NaN        I2       음식      I212
# 96653  MA010120220807288547     퍼스트  NaN        N1  시설관리·임대      N102
# 96654  MA010120220805093794  드림당구클럽  NaN        R1   예술·스포츠      R103
# 96655  MA010120220807227867    대광유통  NaN        G2       소매      G204
# 96656  MA010120220812751792     아시아  NaN        I2       음식      I211
#
#          상권업종중분류명 상권업종소분류코드      상권업종소분류명 표준산업분류코드  ...  \
# 0      철물·건설자재 소매    G21002  벽지/장판/마루 소매업   G47513  ...
# ...

# %%
jb_food = jb[jb['상권업종대분류명'] == '음식'][columns]
jb_store = jb[(jb['상권업종소분류명'] == '편의점') | (jb['상권업종소분류명'] == '슈퍼마켓')][columns]
jb_sports = jb[jb['상권업종중분류명'] == '스포츠 서비스'][columns]

jb_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
jb_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
jb_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 제주

# %%
jeju = pd.read_csv("상가정보_제주.csv", encoding = "utf-8")
print(jeju)
# Out:
#                      상가업소번호          상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220806280927        올인테리어   NaN        M1    과학·기술      M112
# 1      MA010120220806280944      청호나이스렌탈  서귀포점        N1  시설관리·임대      N110
# 2      MA010120220805097241  퍼시픽렌터카제주영업소   NaN        N1  시설관리·임대      N109
# 3      MA010120220807370456   제이원테니스아카데미   NaN        P1       교육      P106
# 4      MA010120220809678568         펀빌리티   NaN        P1       교육      P106
# ...                     ...          ...   ...       ...      ...       ...
# 57860  MA010120220809980928          서서히   NaN        I2       음식      I212
# 57861  MA010120220809680503        덮다&요남   NaN        I2       음식      I210
# 57862  MA010120220803806845           코루   NaN        N1  시설관리·임대      N110
# 57863  MA010120220811828359     지오드림인테리어   NaN        M1    과학·기술      M112
# 57864  MA010120220808411139      투빅커피효돈점   NaN        I2       음식      I212
#
# ...

# %%
jeju_food = jeju[jeju['상권업종대분류명'] == '음식'][columns]
jeju_store = jeju[(jeju['상권업종소분류명'] == '편의점') | (jeju['상권업종소분류명'] == '슈퍼마켓')][columns]
jeju_sports = jeju[jeju['상권업종중분류명'] == '스포츠 서비스'][columns]

jeju_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
jeju_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
jeju_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 충남

# %%
cn = pd.read_csv("상가정보_충남.csv", encoding ="utf-8")
print(cn.head())
# Out:
#                  상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  MA010120220806289059    도미당약국  NaN        G2       소매      G215  의약·화장품 소매
# 1  MA010120220806289069   꽃지바다횟집  NaN        I2       음식      I201         한식
# 2  MA010120220806288745  신바람할인매장  NaN        G2       소매      G222   중고 상품 소매
# 3  MA010120220806290247    성도카센타  NaN        S2    수리·개인      S203  자동차 수리·세차
# 4  MA010120220806289855      A민박  NaN        I1       숙박      I101      일반 숙박
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0    G21501         약국   G47811  ...  4421010200103070037035537  NaN
# 1    I20111         횟집   I56114  ...  4482525321102250008002164  NaN
# 2    G22201  중고 상품 소매업   G47862  ...  4421010800103790002000001  NaN
# 3    S20301    자동차 정비소   S95212  ...  4482533025104600006003238  NaN
# 4    I10103         펜션   I55104  ...  4482533028105220007002425  NaN
#
#                       도로명주소   구우편번호  신우편번호  동정보  층정보  호정보          경도  \
# ...

# %%
cn_food = cn[cn['상권업종대분류명'] == '음식'][columns]
cn_store = cn[(cn['상권업종소분류명'] == '편의점') | (cn['상권업종소분류명'] == '슈퍼마켓')][columns]
cn_sports = cn[cn['상권업종중분류명'] == '스포츠 서비스'][columns]

cn_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
cn_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
cn_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")

# %% [markdown]
# # 충북

# %%
cb = pd.read_csv("상가정보_충북.csv", encoding ="utf-8")
print(cb)
# Out:
#                      상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      MA010120220803882649       만도공업사  NaN        S2    수리·개인      S203
# 1      MA010120220808499811          청운  NaN        N1  시설관리·임대      N102
# 2      MA010120220809678259        금성인력  NaN        N1  시설관리·임대      N104
# 3      MA010120220802765372      돈내고돈먹기  NaN        I2       음식      I201
# 4      MA010120220806280718       H&P빵집  NaN        I2       음식      I210
# ...                     ...         ...  ...       ...      ...       ...
# 90949  MA010120220809595222      새봄3056  NaN        N1  시설관리·임대      N111
# 90950  MA010120220806286125  청소년수련마을보람원  NaN        P1       교육      P106
# 90951  MA010120220812767454   그린밧데리할인매장  NaN        G2       소매      G212
# 90952  MA010120220808408521       물소리펜션  NaN        I1       숙박      I101
# 90953  MA010120220812811840  병천토종순대수육국밥  NaN        I2       음식      I201
#
#          상권업종중분류명 상권업종소분류코드          상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
cb_food = cb[cb['상권업종대분류명'] == '음식'][columns]
cb_store = cb[(cb['상권업종소분류명'] == '편의점') | (cb['상권업종소분류명'] == '슈퍼마켓')][columns]
cb_sports = cb[cb['상권업종중분류명'] == '스포츠 서비스'][columns]

cb_food.to_csv("food_industry_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
cb_store.to_csv("convenience_store_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
cb_sports.to_csv("sports_center_data.csv", mode = "a", index=False, header = False, encoding = "utf-8-sig")
